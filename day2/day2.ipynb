# %%
import pandas
import seaborn
from matplotlib import pyplot as plot
# %matplotlib inline
seaborn.set()

# %%
dataframe = pandas.read_csv('train.csv')

dataframe.columns = ['ID', 'Survival', 'Class', 'Name', 'Sex', 'Age', 'Sibling', 'Parent', 'Ticket', 'Price', 'Cabin', 'Boarded']


survived_class2_male_parent = dataframe.groupby('Class').Survival

# %%
dataframe.sample(5)
# Out:
#       ID  Survival  Class                           Name     Sex   Age  \
# 543  544         1      2              Beane, Mr. Edward    male  32.0
# 122  123         0      2           Nasser, Mr. Nicholas    male  32.5
# 642  643         0      3  Skoog, Miss. Margit Elizabeth  female   2.0
# 696  697         0      3               Kelly, Mr. James    male  44.0
# 659  660         0      1     Newell, Mr. Arthur Webster    male  58.0
#
#      Sibling  Parent  Ticket     Price Cabin Boarded
# 543        1       0    2908   26.0000   NaN       S
# 122        1       0  237736   30.0708   NaN       C
# 642        3       2  347088   27.9000   NaN       S
# 696        0       0  363592    8.0500   NaN       S
# 659        0       2   35273  113.2750   D48       C

# %%
dataframe.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dataframe.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataframe['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, dtype: float64

# %%
survived = dataframe[dataframe['Sex'] == 1]

died = dataframe[dataframe['Survived'] == 0]

print("Analysis Report")
print("{0} people survived the titanic".format(survived.shape[0]))
print("{0} people did not the titanic".format(died.shape[0]))


###Percentage Check
percentage_survived = float(len(survived)/len(dataframe))
percentage_survived * 100
# Out:
# Analysis Report
# 342 people survived the titanic
# 549 people did not the titanic
# 38.38383838383838

# %%
#####Pclass
dataframe.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
dataframe.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 30.00    25
# 28.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 33.00    15
# 23.00    15
# 34.00    15
# 39.00    14
# 17.00    13
# 42.00    13
# 40.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 71.00     2
# 59.00     2
# 63.00     2
# 0.83      2
# 30.50     2
# 70.00     2
# 57.00     2
# 0.75      2
# 13.00     2
# 10.00     2
# 64.00     2
# 40.50     2
# 32.50     2
# 45.50     2
# 20.50     1
# 24.50     1
# 0.67      1
# 14.50     1
# 0.92      1
# 74.00     1
# 34.50     1
# 80.00     1
# 12.00     1
# 36.50     1
# 53.00     1
# 55.50     1
# 70.50     1
# 66.00     1
# 23.50     1
# 0.42      1
# Name: Age, dtype: int64

# %%
dataframe.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
dataframe.groupby('Pclass').Survived.value_counts()
# Out:
# Pclass  Survived
# 1       1           136
#         0            80
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: Survived, dtype: int64

# %%
dataframe[['Pclass', 'Survived']].groupby(['Pclass'], as_index=False).mean()
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
pclass = dataframe.groupby('Pclass').Survived.value_counts()

float(136/(136 + 80)) * 100
# Out:
# 62.96296296296296

# %%
dataframe.groupby('Pclass').Survived.mean().plot(kind='bar', grid=True)

# %%
seaborn.barplot(x='Pclass', y='Survived', data=dataframe)

# %%
dataframe.groupby('Age').Survived.value_counts()
# Out:
# Age    Survived
# 0.42   1           1
# 0.67   1           1
# 0.75   1           2
# 0.83   1           2
# 0.92   1           1
# 1.00   1           5
#        0           2
# 2.00   0           7
#        1           3
# 3.00   1           5
#        0           1
# 4.00   1           7
#        0           3
# 5.00   1           4
# 6.00   1           2
#        0           1
# 7.00   0           2
#        1           1
# 8.00   0           2
#        1           2
# 9.00   0           6
#        1           2
# 10.00  0           2
# 11.00  0           3
#        1           1
# 12.00  1           1
# 13.00  1           2
# 14.00  0           3
#        1           3
# 14.50  0           1
#                   ..
# 51.00  0           5
#        1           2
# 52.00  0           3
#        1           3
# 53.00  1           1
# 54.00  0           5
#        1           3
# 55.00  0           1
#        1           1
# 55.50  0           1
# 56.00  0           2
# ...

# %%
dataframe.groupby('Age').Survived.mean().plot(kind='bar', grid=True)

# %%
dataframe.groupby('Sex').Survived.value_counts()
# Out:
# Sex     Survived
# female  1           233
#         0            81
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
dataframe.groupby('Sex').Survived.mean().plot(kind='bar', grid=True)

# %%
dataframe.groupby('Fare').Survived.value_counts()
# Out:
# Fare      Survived
# 0.0000    0           14
#           1            1
# 4.0125    0            1
# 5.0000    0            1
# 6.2375    0            1
# 6.4375    0            1
# 6.4500    0            1
# 6.4958    0            2
# 6.7500    0            2
# 6.8583    0            1
# 6.9500    0            1
# 6.9750    0            1
#           1            1
# 7.0458    0            1
# 7.0500    0            7
# 7.0542    0            2
# 7.1250    0            4
# 7.1417    1            1
# 7.2250    0            9
#           1            3
# 7.2292    0           11
#           1            4
# 7.2500    0           12
#           1            1
# 7.3125    0            1
# 7.4958    0            2
#           1            1
# 7.5208    0            1
# 7.5500    0            3
#           1            1
#                       ..
# 106.4250  0            1
#           1            1
# 108.9000  0            1
#           1            1
# 110.8833  1            3
# ...

# %%
dataframe.groupby('Cabin').Survived.value_counts()
# Out:
# Cabin  Survived
# A10    0           1
# A14    0           1
# A16    1           1
# A19    0           1
# A20    1           1
# A23    1           1
# A24    0           1
# A26    1           1
# A31    1           1
# A32    0           1
# A34    1           1
# A36    0           1
# A5     0           1
# A6     1           1
# A7     0           1
# B101   1           1
# B102   0           1
# B18    1           2
# B19    0           1
# B20    1           2
# B22    0           1
#        1           1
# B28    1           2
# B3     1           1
# B30    0           1
# B35    1           2
# B37    0           1
# B38    0           1
# B39    1           1
# B4     1           1
#                   ..
# E25    1           2
# E31    0           1
# E33    1           2
# E34    1           1
# E36    1           1
# E38    0           1
# E40    1           1
# E44    0           1
#        1           1
# E46    0           1
# E49    1           1
# ...

# %%
dataframe.groupby('Parch').Survived.value_counts()
# Out:
# Parch  Survived
# 0      0           445
#        1           233
# 1      1            65
#        0            53
# 2      0            40
#        1            40
# 3      1             3
#        0             2
# 4      0             4
# 5      0             4
#        1             1
# 6      0             1
# Name: Survived, dtype: int64

# %%
tab = pandas.crosstab(dataframe['Parent'], dataframe['Sex'])

# %%
seaborn.factorplot('Sex', 'Survival', hue='Class', size=4, aspect=2, data=dataframe)

# %%
tab
# Out:
# Sex       female  male
# Survival
# 0             81   468
# 1            233   109

# %%
tab.div(tab.sum(1).astype(float), axis=0).plot(kind="bar", stacked=False)

# %%
seaborn.factorplot(x='Class', y='Survival', hue='Age', col='Boarded', data=dataframe)

# %%
figure = plot.figure(figsize=(15, 5))

ax1 = figure.add_subplot(131)
ax2 = figure.add_subplot(132)
ax3 = figure.add_subplot(133)

seaborn.violinplot(x="Boarded", y="Age", hue="Survival", data=dataframe, split=True, ax=ax1)
seaborn.violinplot(x="Class", y="Age", hue="Survival", data=dataframe, split=True, ax=ax2)
seaborn.violinplot(x="Sex", y="Age", hue="Survival", data=dataframe, split=True, ax=ax3)

# %%
total_survived = dataframe[dataframe['Survival']==1]
total_not_survived = dataframe[dataframe['Survival']==0]
male_survived = dataframe[(dataframe['Survival']==1) & (dataframe['Sex']=="male")]
female_survived = dataframe[(dataframe['Survival']==1) & (dataframe['Sex']=="female")]
male_not_survived = dataframe[(dataframe['Survival']==0) & (dataframe['Sex']=="male")]
female_not_survived = dataframe[(dataframe['Survival']==0) & (dataframe['Sex']=="female")]

plot.figure(figsize=[15,5])
plot.subplot(111)
# seaborn.distplot(total_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='blue')
seaborn.distplot(total_not_survived['Age'].dropna().values, bins=range(0, 81, 1), kde=False, color='red', axlabel='Age')

# %%
male_total = dataframe[(dataframe['Sex']=="male")]

# %%
len(male_total)
# Out:
# 577

# %%
male_survival_percentage = float(len(male_survived)/len(male_total)) * 100

# %%
male_survival_percentage
# Out:
# 18.890814558058924

# %%
plot.figure(figsize=(15, 6))
seaborn.heatmap(dataframe.drop('ID', 1).corr(), vmax=0.6, square=True, annot=True)
